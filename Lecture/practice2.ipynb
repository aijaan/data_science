# %% [markdown]
# ##

# %% [markdown]
# ## 🌳 Мини-проект: Дерево решений «Твой путь в Data Science»
#
# В машинном обучении **Decision Tree (дерево решений)** — это фундамент для таких мощных моделей, как *Random Forest* и *XGBoost*. В этом мини-проекте мы создадим **экспертную систему**, которая имитирует работу дерева решений.
#
# ---
#
# ## 🎯 Задача проекта
#
# Написать **интерактивный классификатор**, который на основе **трёх уровней вопросов** определяет идеальную точку входа в мир Data Science.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## Решение задачи:

# %%
print("Добро пожаловать в распределяющую шляпу мира Data!")
q1 = input("Что тебе ближе: чистая аналитика и математика(1) или разработка и системы(2)?")
if q1 == "1": 
    q2 = input("Тебе интересно искать скрытые смыслы в данных (1) или создавать визуальные отчеты для бизнеса (2)?")
    if q2 == "1":
        q4 = input("Хочешь работать с текстами и картинками (нейросети)(1) или с таблицами и цифрами (2)?")
        if q4 == "1":
            print("Deep Learning Researcher (Исследователь нейросетей)")
        elif q4 == "2":
            print("Data Scientist (Классический исследователь данных)")
    elif q2 == "2":
        print("BI-Analyst (Мастер визуализации и бизнес инсайтов)")
elif q1 == "2":
    q3 = input("Хочешь строить архитектуру хранения данных (1) или внедрять готовые модели в приложении (2)?")
    if q3 == "1":
        q5 = input("Тебе интересны облачные технологии (AWS/Google) (1) или работа с локальными базами (2)?")
        if q5 == "1":
            print("Cloud Data Engineer (Облачный инженер данных)")
        elif q5 == "2":
            print("Data Architect (Архитектор баз данных)")
    elif q3 == "2":
        print("MLOps Engineer (Специалист по деплою и поддержке ML-моделей)")
else:
    print("Ошибка выбора. Попробуй запустить программу снова и вводи только '1' или '2'.")
# Out:
# Добро пожаловать в распределяющую шляпу мира Data!
# Ошибка выбора. Попробуй запустить программу снова и вводи только '1' или '2'.
